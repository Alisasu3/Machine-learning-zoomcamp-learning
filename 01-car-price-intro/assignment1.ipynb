# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv
# Out:
# --2025-09-22 14:17:23--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 874188 (854K) [text/plain]
# Saving to: ‘car_fuel_efficiency.csv.1’
#
# car_fuel_efficiency 100%[===================>] 853.70K  --.-KB/s    in 0.006s
#
# 2025-09-22 14:17:23 (134 MB/s) - ‘car_fuel_efficiency.csv.1’ saved [874188/874188]

# %%
car_df=pd.read_csv("car_fuel_efficiency.csv")

# %%
car_df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
car_df.fuel_type.unique()
# Out:
# array(['Gasoline', 'Diesel'], dtype=object)

# %%
car_df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
car_df[car_df['origin']=='Asia'].fuel_efficiency_mpg.max()
# Out:
# np.float64(23.759122836520497)

# %%
car_df.horsepower.median()
# Out:
# np.float64(149.0)

# %%
car_df.horsepower.value_counts()
# Out:
# horsepower
# 152.0    142
# 145.0    141
# 151.0    134
# 148.0    130
# 141.0    130
#         ...
# 40.0       1
# 57.0       1
# 245.0      1
# 252.0      1
# 61.0       1
# Name: count, Length: 192, dtype: int64

# %%
car_df.horsepower.isnull().sum()
# Out:
# np.int64(708)

# %%
car_df2=car_df.horsepower.fillna(152)

# %%
car_df2.median()
# Out:
# np.float64(152.0)

# %%
car_df3=car_df[car_df['origin']=='Asia']

# %%
import numpy as np

# %%
x=car_df3[['vehicle_weight','model_year']].head(7).values
x.shape[0]
# Out:
# 7

# %%
xt=x.T
xt
# Out:
# array([[2714.21930965, 2783.86897424, 3582.68736772, 2231.8081416 ,
#         2659.43145076, 2844.22753389, 3761.99403819],
#        [2016.        , 2010.        , 2007.        , 2011.        ,
#         2016.        , 2014.        , 2019.        ]])

# %%
xtx=xt.dot(x)
xtx
# Out:
# array([[62248334.33150762, 41431216.5073268 ],
#        [41431216.5073268 , 28373339.        ]])

# %%
v=np.linalg.inv(xtx)
v
# Out:
# array([[ 5.71497081e-07, -8.34509443e-07],
#        [-8.34509443e-07,  1.25380877e-06]])

# %%
y=np.array([1100,1300,800,900,1000,1100,1200])

# %%
w=v.dot(xt).dot(y)

# %%
w.sum()
# Out:
# np.float64(0.5187709081074016)
